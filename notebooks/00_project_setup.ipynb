# %% [markdown]
# # 🚀 Project Setup: Heart Disease Prediction
#
# ## Project Description
# ML project to predict heart disease using clinical features.
#
# ## Setup Steps
# 1. Environment configuration
# 2. Repository initialization
# 3. Folder structure creation
# 4. Dependency installation
# 5. Data download

# %%
# Cell 2: Import and Setup
from google.colab import drive
import os
import sys

# Mount Google Drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# %cd '/content/drive/MyDrive/Dr. Taiwo famuyiwa - Data Science & Biostatistics Portfolio/Machine Learning Projects/Heart-Disease-Prediction'
# Out:
# /content/drive/MyDrive/Dr. Taiwo famuyiwa - Data Science & Biostatistics Portfolio/Machine Learning Projects/Heart-Disease-Prediction

# %%
# 0) Trust GitHub host (prevents host key errors)
# !mkdir -p ~/.ssh && chmod 700 ~/.ssh
# !ssh-keyscan github.com >> ~/.ssh/known_hosts
# !chmod 644 ~/.ssh/known_hosts
# Out:
# # github.com:22 SSH-2.0-85ba476
# # github.com:22 SSH-2.0-85ba476
# # github.com:22 SSH-2.0-85ba476
# # github.com:22 SSH-2.0-85ba476
# # github.com:22 SSH-2.0-85ba476

# %%
# 1) Generate an SSH key if you don't have one yet (press Enter at prompts)
![ -f ~/.ssh/id_ed25519 ] || ssh-keygen -t ed25519 -C "tincorpai@gmail.com"
# Out:
# Generating public/private ed25519 key pair.
# Enter file in which to save the key (/root/.ssh/id_ed25519):
# Enter passphrase (empty for no passphrase):
# Enter same passphrase again:
# Your identification has been saved in /root/.ssh/id_ed25519
# Your public key has been saved in /root/.ssh/id_ed25519.pub
# The key fingerprint is:
# SHA256:CdjagRKcndT0Nu8K6S8p6BeZap8x8Z7x+PaVz7jdjbk tincorpai@gmail.com
# The key's randomart image is:
# +--[ED25519 256]--+
# | ..+.+.          |
# |  o.o+..         |
# |  . o + +        |
# |   . o + +       |
# |    oo. S .      |
# |    +o . .   .   |
# |   oo.=.  . o    |
# |  + o*o*.. . = +.|
# | o.oo.===.. o.E.o|
# +----[SHA256]-----+

# %%
cat /root/.ssh/id_ed25519.pub
# Out:
# ssh-ed25519 AAAAC3NzaC1lZDI1NTE5AAAAIJUkq/K857XVL3fJVGS88wqdmAtVKjXBcNFeiLzjcRlE tincorpai@gmail.com

# %%
# 4) Test the SSH login to GitHub (you should get the success message)
# !ssh -T git@github.com
# Out:
# Hi tincorpai! You've successfully authenticated, but GitHub does not provide shell access.

# %%
# Cell 3: Repository Setup
print("## 🔧 Repository Setup")


# Clone or initialize repository
# !git clone git@github.com:tincorpai/Heart-Disease-Prediction.git
# %cd Heart-Disease-Prediction


# Configure Git
# !git config --global user.name "Taiwo"
# !git config --global user.email "tincorpai@gmail.com"
# Out:
# ## 🔧 Repository Setup
# Cloning into 'Heart-Disease-Prediction'...
# remote: Enumerating objects: 6, done.
# remote: Counting objects: 100% (6/6), done.
# remote: Compressing objects: 100% (4/4), done.
# remote: Total 6 (delta 0), reused 0 (delta 0), pack-reused 0 (from 0)
# Receiving objects: 100% (6/6), done.
# /content/drive/MyDrive/Dr. Taiwo famuyiwa - Data Science & Biostatistics Portfolio/Machine Learning Projects/Heart-Disease-Prediction

# %%
#Create Project Structure
print("## 📁 Creating Project Structure")

project_folders = [
    'data/raw',
    'data/processed',
    'notebooks',
    'src',
    'models',
    'reports/figures',
    'reports/metrics',
    'app'
]
for folder in project_folders:
    os.makedirs(folder, exist_ok=True)
    print(f"✅ Created: {folder}")
# Out:
# ## 📁 Creating Project Structure
# ✅ Created: data/raw
# ✅ Created: data/processed
# ✅ Created: notebooks
# ✅ Created: src
# ✅ Created: models
# ✅ Created: reports/figures
# ✅ Created: reports/metrics
# ✅ Created: app

# %%
print("## 🔄 Initial Git Commit")

# !git add .
# !git commit -m "Initial project setup with folder structure"
# !git push origin master

print("✅ Project setup complete!")
# Out:
# ## 🔄 Initial Git Commit
# [master a20a296] Initial project setup with folder structure
#  1 file changed, 8 insertions(+)
#  create mode 100644 requirements.txt
# Enumerating objects: 4, done.
# Counting objects: 100% (4/4), done.
# Delta compression using up to 2 threads
# Compressing objects: 100% (3/3), done.
# Writing objects: 100% (3/3), 390 bytes | 22.00 KiB/s, done.
# Total 3 (delta 0), reused 0 (delta 0), pack-reused 0
# To github.com:tincorpai/Heart-Disease-Prediction.git
#    3cad588..a20a296  master -> master
# ✅ Project setup complete!

# %%
# %cd '/content/drive/MyDrive/Dr. Taiwo famuyiwa - Data Science & Biostatistics Portfolio/Machine Learning Projects/Heart-Disease-Prediction'
# Out:
# /content/drive/MyDrive/Dr. Taiwo famuyiwa - Data Science & Biostatistics Portfolio/Machine Learning Projects/Heart-Disease-Prediction

# %%
# !git init
# !git config --global user.email "tincorpai@gmail.com"
# !git config --global user.name "Taiwo Famuyiwa"
# Out:
# Reinitialized existing Git repository in /content/drive/MyDrive/Dr. Taiwo famuyiwa - Data Science & Biostatistics Portfolio/Machine Learning Projects/Heart-Disease-Prediction/.git/

# %%
# !git remote add origin https://github.com/tincorpai/Heart-Disease-Prediction.git
# Out:
# error: remote origin already exists.

# %%
# !git remote -v
# Out:
# origin	git@github.com:tincorpai/Heart-Disease-Prediction.git (fetch)
# origin	git@github.com:tincorpai/Heart-Disease-Prediction.git (push)
